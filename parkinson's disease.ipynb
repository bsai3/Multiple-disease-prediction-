# %% [markdown]
# ACC-85

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from matplotlib import pyplot
import pandas as pd
from sklearn.metrics import (confusion_matrix,classification_report)
import seaborn as sns
data=pd.read_csv('/content/parkinsons.csv')
data=pd.DataFrame(data)
print(data.shape)
x=data.drop(columns=['status','name'],axis=1)
y=data['status']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,train_size=0.7,random_state=1)
# define the model
model = RandomForestClassifier()
# fit the model
model.fit(x_train, y_train)
xtep=model.predict(x_test)

# test model evaluvation
ans=classification_report(y_test, xtep)
print(ans)
c=confusion_matrix(y_test,xtep)
sns.heatmap(c,annot=True, fmt="d", cmap="Blues")
pyplot.show()
# Out:
# (195, 24)
#               precision    recall  f1-score   support
#
#            0       0.92      0.63      0.75        19
#            1       0.85      0.97      0.91        40
#
#     accuracy                           0.86        59
#    macro avg       0.89      0.80      0.83        59
# weighted avg       0.87      0.86      0.86        59

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

def load_data(file_path):
    data = pd.read_csv(file_path)
    return data

def preprocess_data(data, drop_columns):
    x = data.drop(columns=drop_columns, axis=1)
    y = data['status']
    return x, y

def train_model(x_train, y_train):
    model = RandomForestClassifier()
    model.fit(x_train, y_train)
    return model

def evaluate_model(model, x_test, y_test):
    y_pred = model.predict(x_test)
    print(classification_report(y_test, y_pred))
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.show()

def plot_feature_importance(model, columns):
    importance = model.feature_importances_
    plt.figure().set_figwidth(35)
    plt.bar(columns, importance)
    plt.show()

# Load and preprocess Parkinson's data
parkinsons_data = load_data('/content/parkinsons.csv')
x, y = preprocess_data(parkinsons_data, ['status', 'name'])

# Split data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, train_size=0.7, random_state=1)

# Train model and evaluate on Parkinson's data
parkinsons_model = train_model(x_train, y_train)
evaluate_model(parkinsons_model, x_test, y_test)
plot_feature_importance(parkinsons_model, x.columns)

# Load and preprocess Book1 data
book1_data = load_data('/content/Book1.csv')
x, y = preprocess_data(book1_data, ['status'])

# Split data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, train_size=0.7, random_state=1)

# Train model and evaluate on Book1 data
book1_model = train_model(x_train, y_train)
evaluate_model(book1_model, x_test, y_test)

# %% [markdown]
# feature extrction

# %%
import matplotlib.pyplot as plt
column_names=list(data.columns.values)
print(column_names)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
  print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.figure().set_figwidth(35)
plt.bar([x for x in x.columns], importance)
plt.show()
# Out:
# ['name', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)', 'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP', 'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5', 'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA', 'spread1', 'spread2', 'D2', 'PPE']
# Feature: 0, Score: 0.09693
# Feature: 1, Score: 0.06566
# Feature: 2, Score: 0.04116
# Feature: 3, Score: 0.03340
# Feature: 4, Score: 0.04647
# Feature: 5, Score: 0.05145
# Feature: 6, Score: 0.02261
# Feature: 7, Score: 0.07121
# Feature: 8, Score: 0.02083
# Feature: 9, Score: 0.03751
# Feature: 10, Score: 0.02961
# Feature: 11, Score: 0.02429
# Feature: 12, Score: 0.02445
# Feature: 13, Score: 0.03890
# Feature: 14, Score: 0.02534
# Feature: 15, Score: 0.02489
# Feature: 16, Score: 0.02606
# Feature: 17, Score: 0.02223
# Feature: 18, Score: 0.11982
# Feature: 19, Score: 0.02813
# Feature: 20, Score: 0.04287
# Feature: 21, Score: 0.10620

# %% [markdown]
# after feature extraction acc-85

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from matplotlib import pyplot
import pandas as pd
from sklearn.metrics import (confusion_matrix,classification_report)
import seaborn as sns
data=pd.read_csv('/content/Book1.csv')
print(data.shape)
x=data.drop(columns=['status'],axis=1)
y=data['status']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,train_size=0.7,random_state=1)
# define the model
model = RandomForestClassifier()
# fit the model
model.fit(x_train, y_train)
xtep=model.predict(x_test)

# test model evaluvation
ans=classification_report(y_test, xtep)
print(ans)
c=confusion_matrix(y_test,xtep)
sns.heatmap(c,annot=True, fmt="d", cmap="Blues")
pyplot.show()
# Out:
# (195, 5)
#               precision    recall  f1-score   support
#
#            0       1.00      0.63      0.77        19
#            1       0.85      1.00      0.92        40
#
#     accuracy                           0.88        59
#    macro avg       0.93      0.82      0.85        59
# weighted avg       0.90      0.88      0.87        59

# %% [markdown]
# result

# %%
a=(236.2,-6.816086,0.01426,0.119652)
# MDVP:Fo(Hz),spread1,Shimmer:APQ5,PPE
anp=np.asarray(a)
r=anp.reshape(1,-1)
p=model.predict(r)
print(p[0])
if p[0]==0:
  print("The person is not park")
else:
  print("The person is park")
# Out:
# 0
# The person is not park
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

def load_data(filename):
    data = pd.read_csv(filename)
    return data

def preprocess_data(data, drop_columns):
    x = data.drop(columns=drop_columns, axis=1)
    y = data['status']
    return x, y

def train_model(x_train, y_train):
    model = RandomForestClassifier()
    model.fit(x_train, y_train)
    return model

def evaluate_model(model, x_test, y_test):
    y_pred = model.predict(x_test)
    print(classification_report(y_test, y_pred))
    sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues")
    plt.show()

def plot_feature_importance(model, columns):
    importance = model.feature_importances_
    for i,v in enumerate(importance):
      print('Feature: %0d, Score: %.5f' % (i,v))
    plt.figure().set_figwidth(35)
    plt.bar(columns, importance)
    plt.show()

def main():
    # Load first dataset
    data1 = load_data('/content/parkinsons.csv')
    x1, y1 = preprocess_data(data1, ['status', 'name'])
    x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size=0.3, train_size=0.7, random_state=1)
    model1 = train_model(x_train1, y_train1)
    print("Before Feature Extration:")
    evaluate_model(model1, x_test1, y_test1)
    print()
    plot_feature_importance(model1, x1.columns)

    # Load second dataset
    data2 = load_data('/content/Book1.csv')
    x2, y2 = preprocess_data(data2, ['status'])
    x_train2, x_test2, y_train2, y_test2 = train_test_split(x2, y2, test_size=0.3, train_size=0.7, random_state=1)
    model2 = train_model(x_train2, y_train2)
    print("After Feature Extration:")
    evaluate_model(model2, x_test2, y_test2)

if __name__ == "__main__":
    main()
# Out:
# Before Feature Extration:
#               precision    recall  f1-score   support
#
#            0       0.91      0.53      0.67        19
#            1       0.81      0.97      0.89        40
#
#     accuracy                           0.83        59
#    macro avg       0.86      0.75      0.78        59
# weighted avg       0.84      0.83      0.82        59
# Feature: 0, Score: 0.10577
# Feature: 1, Score: 0.04927
# Feature: 2, Score: 0.04323
# Feature: 3, Score: 0.03067
# Feature: 4, Score: 0.02137
# Feature: 5, Score: 0.06193
# Feature: 6, Score: 0.03347
# Feature: 7, Score: 0.06008
# Feature: 8, Score: 0.01910
# Feature: 9, Score: 0.03580
# Feature: 10, Score: 0.03604
# Feature: 11, Score: 0.03125
# Feature: 12, Score: 0.03054
# Feature: 13, Score: 0.03780
# Feature: 14, Score: 0.02917
# Feature: 15, Score: 0.02296
# Feature: 16, Score: 0.02812
# Feature: 17, Score: 0.01542
# Feature: 18, Score: 0.08961
# Feature: 19, Score: 0.01924
# Feature: 20, Score: 0.05102
# ...
